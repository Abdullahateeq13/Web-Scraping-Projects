# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://greenstocknews.com/stocks/electric-vehicle-stocks"

r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
table = soup.find('div', class_="table-content stockslist-items")

# %%
Stock_Name = []
Last_Trade = []
Change = []
Volume = []
Shares = []
Market = []

for items in table:
    rows = items.find('div',class_="stock-data")
    
    for row in rows:
        
        stock_name = row.find('div', class_="stock-name")
        Stock_Name.append(stock_name.text.strip())

        last_trade = row.find('div',class_="last-trade")
        Last_Trade.append(last_trade.text.strip())
        
        change = row.find('div',class_="market-change")
        Change.append(change.text.strip())
        
        volume = row.find('div',class_="volume-average")
        Volume.append(volume.text.strip())
        
        shares = row.find('div',class_="range-high-low")
        Shares.append(shares.text.strip())
        
        market_cap = row.find('div', class_="market-cap")
        Market.append(market_cap.text.strip())

# %%
columns = {
    'Stocks_Name': Stock_Name,
    'Last_Trade': Last_Trade,
    'Change': Change,
    'Volume': Volume,
    'Shares': Shares,
    'Market_Cap': Market
    
}

# %%
df = pd.DataFrame(columns, index = None)

# %%
df
# Out:
#                                Stocks_Name  Last_Trade  \
# 0              NASDAQ GP  GREENPOWER MOTOR    US$ 2.85
# 1                       NASDAQ TSLA  TESLA  US$ 169.15
# 2                    NYSE TM  TOYOTA MOTOR  US$ 140.85
# 3                             NYSE F  FORD   US$ 11.86
# 4                  NYSE GM  GENERAL MOTORS   US$ 33.28
# 5               OTCMKTS BYDDF  BYD COMPANY   US$ 30.33
# 6                       NASDAQ LI  LI AUTO   US$ 24.77
# 7                            NYSE NIO  NIO    US$ 8.16
# 8                NASDAQ LCID  LUCID MOTORS    US$ 7.28
# 9           NASDAQ RIVN  RIVIAN AUTOMOTIVE   US$ 13.86
# 10                        NYSE XPEV  XPENG   US$ 10.09
# 11        NASDAQ PSNY  POLESTAR AUTOMOTIVE    US$ 3.97
# 12                NASDAQ NWTN  NWTN MOTORS   US$ 10.71
# 13                        NYSE FSR  FISKER    US$ 6.15
# 14             NYSE ZEV  LIGHTNING EMOTORS    US$ 5.61
# 15                  NASDAQ BLBD  BLUE BIRD   US$ 18.63
# 16                     NASDAQ NKLA  NIKOLA    US$ 0.86
# 17                OTCMKTS NFYEF  NFI GROUP    US$ 7.41
# 18         NYSE LEV  LION ELECTRIC COMPANY    US$ 2.21
# 19                      NASDAQ GOEV  CANOO    US$ 0.68
# 20         NASDAQ KNDI  KANDI TECHNOLOGIES    US$ 3.15
# 21          NASDAQ MULN  MULLEN AUTOMOTIVE    US$ 1.44
# 22                  NASDAQ WKHS  WORKHORSE    US$ 0.98
# 23             NASDAQ FFIE  FARADAY FUTURE    US$ 0.24
# 24           OTCMKTS FHYDF  FIRST HYDROGEN    US$ 2.04
# 25     NASDAQ CENN  CENNTRO ELECTRIC GROUP    US$ 0.39
# 26                         NASDAQ XOS  XOS    US$ 0.48
# 27           NASDAQ RIDE  LORDSTOWN MOTORS    US$ 0.34
# 28              NASDAQ REE  REE AUTOMOTIVE    US$ 0.33
# 29  NASDAQ SOLO  ELECTRAMECCANICA VEHICLES    US$ 0.53
# 30        NASDAQ EVTV  ENVIROTECH VEHICLES    US$ 2.41
# 31              NASDAQ VEV  VICINITY MOTOR    US$ 0.78
# 32                    NASDAQ ARVL  ARRIVAL    US$ 2.24
# 33                     NASDAQ VLCN  VOLCON    US$ 1.20
# 34         NASDAQ ELMS  ELECTRIC LAST MILE    US$ 0.19
# 35                       NASDAQ AYRO  AYRO    US$ 0.51
# 36        NASDAQ AMV  ATLIS MOTOR VEHICLES    US$ 0.53
# 37               NASDAQ PEV  PHOENIX MOTOR    US$ 0.85
# 38     NASDAQ GTEC  GREENLAND TECHNOLOGIES    US$ 1.22
# 39                    NASDAQ FUV  ARCIMOTO    US$ 1.66
# 40      OTCMKTS EVTGF  EV TECHNOLOGY GROUP    US$ 0.04
#
#                          Change   Volume   Shares    Market_Cap
# 0           0.13 4.78 0.13 4.78   35,063   25.78M   US$ 73.470M
# 1       -2.64 -1.54 -2.64 -1.54   88.55M    3.17B  US$ 536.210B
# 2           3.04 2.21 3.04 2.21  398,730    1.36B  US$ 191.560B
# 3       -0.16 -1.33 -0.16 -1.33   41.60M    3.92B   US$ 46.490B
# 4       -0.38 -1.13 -0.38 -1.13   10.41M    1.39B   US$ 46.260B
# 5       -0.07 -0.23 -0.07 -0.23   62,828    1.10B   US$ 33.360B
# 6           0.02 0.08 0.02 0.08    7.38M  977.18M   US$ 24.200B
# 7       -0.11 -1.33 -0.11 -1.33   24.56M    1.67B   US$ 13.630B
# 8       -0.43 -5.58 -0.43 -5.58   28.89M    1.83B   US$ 13.320B
# 9       -0.01 -0.07 -0.01 -0.07   29.65M  931.51M   US$ 12.910B
# 10      -0.46 -4.36 -0.46 -4.36   11.94M  862.77M    US$ 8.710B
# 11      -0.15 -3.64 -0.15 -3.64    2.88M    2.13B    US$ 8.460B
# 12          0.05 0.47 0.05 0.47    7,077  253.47M    US$ 2.710B
# 13      -0.47 -7.10 -0.47 -7.10   13.68M  187.66M    US$ 1.150B
# 14      -0.22 -3.77 -0.22 -3.77  226,444  113.05M  US$ 634.210M
# 15      -1.12 -5.67 -1.12 -5.67  566,780   32.03M  US$ 596.720M
# 16    -0.13 -13.04 -0.13 -13.04   44.13M  631.39M  US$ 540.790M
# 17      -0.59 -7.38 -0.59 -7.38    3,163   70.98M  US$ 526.100M
# 18      -0.19 -7.92 -0.19 -7.92  977,908  221.03M  US$ 488.480M
# 19      -0.05 -7.34 -0.05 -7.34   19.29M  477.05M  US$ 322.960M
# 20          0.11 3.62 0.11 3.62  127,479   74.19M  US$ 233.700M
# 21      -0.04 -2.70 -0.04 -2.70   15.10M  151.69M  US$ 218.430M
# 22      -0.06 -5.53 -0.06 -5.53    8.84M  170.82M  US$ 167.830M
# 23      -0.02 -7.93 -0.02 -7.93   57.98M  638.48M  US$ 155.730M
# 24      -0.06 -2.79 -0.06 -2.79    5,115   61.05M  US$ 124.630M
# 25      -0.02 -3.85 -0.02 -3.85    1.04M  261.31M  US$ 100.600M
# 26  -0.0044 -0.90 -0.0044 -0.90  282,322  169.83M   US$ 82.110M
# 27      -0.03 -8.41 -0.03 -8.41    4.46M  239.03M   US$ 81.270M
# 28          0.02 6.80 0.02 6.80  373,665  244.86M   US$ 80.780M
# 29  -0.0085 -1.59 -0.0085 -1.59  281,078  119.29M   US$ 62.640M
# 30      -0.06 -2.42 -0.06 -2.42    7,585   15.02M   US$ 36.200M
# 31  -0.0079 -1.00 -0.0079 -1.00   55,569   44.03M   US$ 34.440M
# 32      -0.20 -8.20 -0.20 -8.20  490,265   15.26M   US$ 34.180M
# 33      -0.06 -4.61 -0.06 -4.61   47,119   24.62M   US$ 29.540M
# 34          0.00 0.00 0.00 0.00        0  124.03M   US$ 23.370M
# 35      0.0003 0.06 0.0003 0.06   51,431   37.35M   US$ 19.200M
# 36  -0.0003 -0.06 -0.0003 -0.06  177,893   33.14M   US$ 17.550M
# 37      -0.02 -2.30 -0.02 -2.30   11,635   20.28M   US$ 17.240M
# 38      -0.07 -5.43 -0.07 -5.43  664,873   12.98M   US$ 15.840M
# 39          0.01 0.61 0.01 0.61   74,110    7.34M   US$ 12.180M
# 40    -0.05 -53.37 -0.05 -53.37   22,700  108.25M    US$ 4.340M

# %%
df = df[df['Stocks_Name'].str.contains('NASDAQ')]

# %%
df.to_excel('ev_stocks.xlsx', index=None)
